# %%
import cv2

# %%
# Load the cascade
face_cascade = cv2.CascadeClassifier('C:/Users/PROMIT/Desktop/DFT/facehar.xml')

# %%
# Read the input image
img = cv2.imread('C:/Users/PROMIT/Desktop/contents/matlab/mine.jpg')

# %%
import cv2 as cv
import sys
cv2.namedWindow('output', cv2.WINDOW_NORMAL)
img = cv.imread('C:/Users/PROMIT/Desktop/contents/matlab/mine.jpg')
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.1, 4)
if img is None:
    sys.exit("Could not read the image.")

# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
# Display the output
cv2.imshow('output', img)
k = cv.waitKey(0)

#if k == ord("s"):
   # cv.imwrite("mine.png", img)

# %%
# !pip install opencv-contrib-python

# %%
recognizer = cv2.face.LBPHFaceRecognizer_create()

# %%
import pickle
labels={}

# %%
with open("labels5.pickle",'rb') as f:
    labels=pickle.load(f)
    labels={v:k for k,v in labels.items()}

# %%
import numpy as np
cv2.namedWindow('frame', cv2.WINDOW_NORMAL)
recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read("trainner4.yml")
cap=cv2.VideoCapture(0)

while(True):
    #Capture frame by frame
    ret,frame=cap.read()
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

    cv2.imwrite('my_image.png',frame)
    faces=face_cascade.detectMultiScale(gray,scaleFactor=1.5,minNeighbors=5)
    for (x,y,w,h) in faces:
        #print(x,y,w,h)
        roi_gray=gray[y:y+h,x:x+w]
        roi_color=frame[y:y+h,x:x+w]
        #img_item="my_image.png"
        #cv2.imwrite(img_item,roi_gray)
        id_,conf=recognizer.predict(roi_gray)
        if conf>45:
            print(id_)
            print(labels[id_])
            font=cv2.FONT_HERSHEY_SIMPLEX
            name=labels[id_]
            color=(255,255,255)
            stroke=2
            cv2.putText(frame,name,(x,y),font,1,color,stroke,cv2.LINE_AA)
            
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 230, 211), 2)
    #Display the resulting frame
    cv2.imshow('frame',frame)
    if cv2.waitKey(20)& 0xFF == ord('q'):
        break
#When everything is done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 5
# promit
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# peter-dinklage
# 4
# ...
